# %%
pip install openai

# %%
from openai import OpenAI
client = OpenAI(api_key="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")

def call_llm(messages, model="gpt-4o-mini", temperature=0.5):
    response = client.responses.create(
        model=model,
        input=messages,
        temperature=temperature
    )
    return response.output_text


messages = [
    {"role": "user", "content": "Explain OpenAI."}
]

print(call_llm(messages))
# Out:
# OpenAI is an artificial intelligence research organization that aims to ensure that artificial general intelligence (AGI) benefits all of humanity. Founded in December 2015, OpenAI conducts research in various areas of AI, including machine learning, natural language processing, robotics, and more.
#
# ### Key Objectives:
# 1. **Safety and Ethics**: OpenAI focuses on developing AI technologies that are safe and aligned with human values.
# 2. **Collaboration**: The organization collaborates with other research institutions, policymakers, and the public to promote understanding and responsible use of AI.
# 3. **Accessibility**: OpenAI aims to make AI technologies widely available while ensuring that their benefits are distributed fairly.
#
# ### Notable Projects:
# - **GPT Models**: OpenAI has developed several versions of the Generative Pre-trained Transformer (GPT), which are capable of understanding and generating human-like text.
# ...

# %%
messages = [
    {"role": "user", "content": "Explain Prompt Engineering."}
]

print(call_llm(messages))
# Out:
# Prompt engineering is the process of designing and refining the input prompts given to AI models, particularly large language models like GPT-3 or similar systems, to achieve specific, desired outputs. This practice is crucial because the quality and relevance of the AI's responses can significantly depend on how the prompt is structured.
#
# ### Key Components of Prompt Engineering:
#
# 1. **Clarity**: The prompt should be clear and unambiguous. Vague prompts can lead to unexpected or irrelevant responses.
#
# 2. **Context**: Providing context helps the AI understand the situation or background. This can include examples, specific instructions, or setting the tone.
#
# 3. **Specificity**: Being specific about what you want can guide the model towards generating more relevant content. For example, instead of asking "Tell me about dogs," you might say, "List five characteristics of Golden Retrievers."
#
# ...
